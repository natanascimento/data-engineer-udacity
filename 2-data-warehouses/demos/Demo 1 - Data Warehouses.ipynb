# %%
# !pip install psycopg2-binary
# !pip install ipython-sql
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 1.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 781 kB/s eta 0:00:01
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13699 sha256=2fcdfd1a140eef6cf00f03ff5c2130c0f009039acb96c36a82c90f5060e8925a
#   Stored in directory: /Users/u006499/Library/Caches/pip/wheels/48/6d/77/9517cb933af254f51a446f1a5ec9c2be3e45f17384940bce68
# Successfully built prettytable
# ...

# %%
# %load_ext sql

# %%
DB_ENDPOINT= '172.21.0.2'
DB_PORT= '5432'
DB_USER='natan'
DB_PASSWORD='natan123'
DB='dw_udacity'

#postgresql://username:password@host:port/database
conn_string = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_ENDPOINT}:{DB_PORT}/{DB}"
        
print(conn_string)
# Out:
# postgresql://natan:natan123@172.21.0.2:5432/dw_udacity

# %%
# %sql $conn_string
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ...
